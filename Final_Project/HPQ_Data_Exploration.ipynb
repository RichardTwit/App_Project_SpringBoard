# %% [markdown]
# <a href="https://colab.research.google.com/github/RichardTwit/App_Project_SpringBoard/blob/main/Final_Project/HPQ_Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/HPQ_Updated.csv")

# %%
df
# Out:
#        Unnamed: 0        date    volume       open       high        low  \
# 0              19  2020-06-05  19470700  17.200001  17.639999  17.129999
# 1              20  2020-06-04  20873100  16.480000  16.870001  16.320000
# 2              21  2020-06-03  19391500  16.150000  16.980000  16.049999
# 3              22  2020-06-02  28266700  15.240000  15.870000  15.010000
# 4              23  2020-06-01  19564600  15.050000  15.580000  14.950000
# ...           ...         ...       ...        ...        ...        ...
# 12716       12735  1970-01-08   3325900   0.370757   0.379183   0.370313
# 12717       12736  1970-01-07   1014600   0.370313   0.372087   0.370313
# 12718       12737  1970-01-06   2395700   0.373861   0.374305   0.369870
# 12719       12738  1970-01-05   4368700   0.363661   0.375192   0.363661
# 12720       12739  1970-01-02   1324700   0.365435   0.365435   0.361443
#
#            close   adjclose  CDL3LINESTRIKE  CDLDOJI  ...        MFI  \
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#              date    volume       open       high        low      close  \
# 0      2020-06-05  19470700  17.200001  17.639999  17.129999  17.410000
# 1      2020-06-04  20873100  16.480000  16.870001  16.320000  16.469999
# 2      2020-06-03  19391500  16.150000  16.980000  16.049999  16.860001
# 3      2020-06-02  28266700  15.240000  15.870000  15.010000  15.790000
# 4      2020-06-01  19564600  15.050000  15.580000  14.950000  15.130000
# ...           ...       ...        ...        ...        ...        ...
# 12716  1970-01-08   3325900   0.370757   0.379183   0.370313   0.374305
# 12717  1970-01-07   1014600   0.370313   0.372087   0.370313   0.370757
# 12718  1970-01-06   2395700   0.373861   0.374305   0.369870   0.369870
# 12719  1970-01-05   4368700   0.363661   0.375192   0.363661   0.373861
# 12720  1970-01-02   1324700   0.365435   0.365435   0.361443   0.363217
#
#         adjclose  CDL3LINESTRIKE  CDLDOJI  CDLGRAVESTONEDOJI  ...        MFI  \
# ...

# %%
df.columns
# Out:
# Index(['date', 'volume', 'open', 'high', 'low', 'close', 'adjclose',
#        'CDL3LINESTRIKE', 'CDLDOJI', 'CDLGRAVESTONEDOJI', 'CDLHARAMI',
#        'CDLHARAMICROSS', 'CDLHIKKAKEMOD', 'CDLHOMINGPIGEON',
#        'CDLINVERTEDHAMMER', 'CDLLONGLEGGEDDOJI', 'CDLMATCHINGLOW',
#        'CDLRICKSHAWMAN', 'CDLSTICKSANDWICH', 'Support_Level',
#        'Resistance_Level', 'MFI', 'VWAP', 'Swing_High', 'Swing_Low',
#        'Fib_Retracement_0.382', 'Fib_Retracement_0.618', 'MACD', 'Signal Line',
#        'RSI_14', 'EMA_14'],
#       dtype='object')

# %%
candle_columns= ['CDL3LINESTRIKE', 'CDLDOJI', 'CDLGRAVESTONEDOJI', 'CDLHARAMI',
       'CDLHARAMICROSS', 'CDLHIKKAKEMOD', 'CDLHOMINGPIGEON',
       'CDLINVERTEDHAMMER', 'CDLLONGLEGGEDDOJI', 'CDLMATCHINGLOW',
       'CDLRICKSHAWMAN', 'CDLSTICKSANDWICH']

# %%
import pandas as pd
import matplotlib.pyplot as plt




df_transposed = df[candle_columns].T


df_transposed.plot(kind='bar')


plt.title('Bar Graph of Columns')
plt.xlabel('Columns')
plt.ylabel('Value')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt




df['date'] = pd.to_datetime(df['date'])


df.set_index('date', inplace=True)


columns_to_plot = ['open', 'close', 'high', 'low']


fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))


for i, ax in enumerate(axes.flatten()):
    column = columns_to_plot[i]
    df[column].plot(ax=ax, linestyle='-', marker='o', markersize=4)
    ax.set_title(column.capitalize())


plt.tight_layout()


fig.suptitle('Trading Data Time Series')
fig.text(0.5, 0.04, 'Date', ha='center')
fig.text(0.04, 0.5, 'Price', va='center', rotation='vertical')


plt.show()

# %%
# !pip install mplfinance

# %%
import pandas as pd
import plotly.graph_objects as go


df.reset_index(inplace=True)

df['date'] = pd.to_datetime(df['date'])


fig = go.Figure(data=[go.Candlestick(x=df['date'],
                                     open=df['open'],
                                     high=df['high'],
                                     low=df['low'],
                                     close=df['close'])])


fig.update_layout(title='Trading Data Candlestick Chart',
                  xaxis_title='Date',
                  yaxis_title='Price')


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt




value_counts = df[candle_columns].apply(pd.value_counts)

print(value_counts)


fig, ax = plt.subplots()

value_counts.plot(kind='bar', ax=ax)


plt.title('Value Counts of Columns')
plt.xlabel('Columns')
plt.ylabel('Count')


plt.xticks(rotation=90)


plt.show()
# Out:
#      CDL3LINESTRIKE  CDLDOJI  CDLGRAVESTONEDOJI  CDLHARAMI  CDLHARAMICROSS  \
# 0             12720    12706              12713      11280           12719
# 100               1       15                  8       1441               2
#
#      CDLHIKKAKEMOD  CDLHOMINGPIGEON  CDLINVERTEDHAMMER  CDLLONGLEGGEDDOJI  \
# 0            12707            11282              12708              12706
# 100             14             1439                 13                 15
#
#      CDLMATCHINGLOW  CDLRICKSHAWMAN  CDLSTICKSANDWICH
# 0             11414           12714             12719
# 100            1307               7                 2

# %%
import pandas as pd
import matplotlib.pyplot as plt


#df['date'] = pd.to_datetime(df['date'])


#df.set_index('date', inplace=True)


columns_to_plot = ['Support_Level', 'Resistance_Level']


ax = df[columns_to_plot].plot(figsize=(10, 6))


plt.title('Trading Data Time Series')
plt.xlabel('Date')
plt.ylabel('Price')


ax.set_ylim(df[columns_to_plot].min().min() - 1, df[columns_to_plot].max().max() + 1)



plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


df['date'] = pd.to_datetime(df['date'])


df.set_index('date', inplace=True)


columns_to_plot = ['open', 'close', 'high', 'low']

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))


for i, ax in enumerate(axes.flatten()):
    column = columns_to_plot[i]
    df[column].plot(ax=ax, linestyle='-', marker='o', markersize=4)
    ax.set_title(column.capitalize())


plt.tight_layout()


fig.suptitle('Trading Data Time Series')
fig.text(0.5, 0.04, 'Date', ha='center')
fig.text(0.04, 0.5, 'Price', va='center', rotation='vertical')


plt.show()

# %%
#df['date'] = pd.to_datetime(df['date'])


df.reset_index('date', inplace=True)


columns_to_plot = ['MFI', 'RSI_14']


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 8))


for i, ax in enumerate(axes.flatten()):
    column = columns_to_plot[i]
    df.plot.scatter(x='date', y=column, ax=ax, marker='o', s=30)
    ax.set_title(column.capitalize())


plt.tight_layout()


fig.suptitle('Trading Data Time Series')
fig.text(0.5, 0.04, 'Date', ha='center')
fig.text(0.04, 0.5, 'Value', va='center', rotation='vertical')


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


#df['date'] = pd.to_datetime(df['date'])


#df.set_index('date', inplace=True)


columns_to_plot = ['Fib_Retracement_0.382', 'Fib_Retracement_0.618']


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 8))


for i, ax in enumerate(axes.flatten()):
    column = columns_to_plot[i]
    df[column].plot(ax=ax, linestyle='-', marker='o', markersize=4)
    ax.set_title(column.capitalize())


plt.tight_layout()


fig.suptitle('Trading Data Time Series')
fig.text(0.5, 0.04, 'Date', ha='center')
fig.text(0.04, 0.5, 'Price', va='center', rotation='vertical')


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


#df['date'] = pd.to_datetime(df['date'])


#df.set_index('date', inplace=True)


columns_to_plot = ['Swing_High', 'Swing_Low']


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 8))


for i, ax in enumerate(axes.flatten()):
    column = columns_to_plot[i]
    df[column].plot(ax=ax, linestyle='-', marker='o', markersize=4)
    ax.set_title(column.capitalize())


plt.tight_layout()


fig.suptitle('Trading Data Time Series')
fig.text(0.5, 0.04, 'Date', ha='center')
fig.text(0.04, 0.5, 'Price', va='center', rotation='vertical')


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


#df['date'] = pd.to_datetime(df['date'])


#df.set_index('date', inplace=True)


columns_to_plot = ['MACD', 'Signal Line',
       'VWAP', 'EMA_14']  # Add or remove columns as needed


fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))


for i, ax in enumerate(axes.flatten()):
    column = columns_to_plot[i]
    df[column].plot(ax=ax, linestyle='-', marker='o', markersize=4)
    ax.set_title(column.capitalize())


plt.tight_layout()


fig.suptitle('Trading Data Time Series')
fig.text(0.5, 0.04, 'Date', ha='center')
fig.text(0.04, 0.5, 'Price', va='center', rotation='vertical')


plt.show()

# %%
df.corr()
# Out:
# <ipython-input-41-2f6f6606aa2c>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#                          volume      open      high       low     close  \
# volume                 1.000000  0.398073  0.400395  0.395276  0.397847
# open                   0.398073  1.000000  0.999757  0.999748  0.999565
# high                   0.400395  0.999757  1.000000  0.999648  0.999792
# low                    0.395276  0.999748  0.999648  1.000000  0.999785
# close                  0.397847  0.999565  0.999792  0.999785  1.000000
# adjclose               0.379034  0.965451  0.964431  0.966757  0.965733
# CDL3LINESTRIKE         0.001539  0.015275  0.014963  0.013997  0.014052
# CDLDOJI                0.000781  0.042436  0.043757  0.042311  0.043579
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


correlation_matrix = df.corr()


plt.figure(figsize=(30, 30))


sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')


plt.title('Trading Data Correlation Matrix')


plt.show()
# Out:
# <ipython-input-42-bc7bcafd2b17>:6: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
